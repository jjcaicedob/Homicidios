# %%
# A histogram is a graph showing frequency distributions.
# sbs = Step By Step

# Import the necessary libraries 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
# Load a CSV file into a Pandas DataFrame
df = pd.read_csv("homicidios_clean.csv")

# %%
# Return a tuple representing the dimensionality of the DataFrame.
# First value  = Number of Rows including the header.
# Second value = Number of Columns.
df.shape
# Out:
# (76467, 7)

# %%
# Get the frequency table for the column CANTIDAD
df['CANTIDAD'].value_counts().sort_index()
# Out:
# CANTIDAD
# 1     69757
# 2      5673
# 3       768
# 4       182
# 5        48
# 6        14
# 7        12
# 8         5
# 9         1
# 10        3
# 11        2
# 16        2
# Name: count, dtype: int64

# %%
# In Matplotlib, we use the hist() function to create histograms.
# The hist() function will read the array and produce a histogram.

# Create a histogram with CANTIDAD column
plt.hist(df.CANTIDAD)

# Display the histogram
plt.show()

# %%
# Get the number of deaths without repetitions
valores_cantidad = df.CANTIDAD.unique()

# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Create a histogram with CANTIDAD column
plt.hist(df.CANTIDAD, color="gray")

# Display the histogram
plt.show()

# %%
# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="gray")

# Display the histogram
plt.show()

# %%
# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="gray")

# Add frequency labels above each bar
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, str(int(n[i])), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()

# %%
# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Function to format values ​​with thousands separators
formatter = FuncFormatter(lambda x, pos: f'{int(x):,}'.replace(',', '.'))

# Format the Y axis
plt.gca().yaxis.set_major_formatter(formatter)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Create a histogram with CANTIDAD column
n, bins, patches = plt.hist(df.CANTIDAD, color="gray")

# Add frequency labels above each bar, in thousands format
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, f'{int(n[i]):,}'.replace(',', '.'), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()

# %%
# Make sure all values ​​on the X axis are visible
plt.xticks(valores_cantidad)

# Format the Y axis
plt.gca().yaxis.set_major_formatter(formatter)

# Add tags and title
plt.title('Histograma de CANTIDAD de Homicidios')
plt.xlabel('Cantidad de homicidios')
plt.ylabel('Frecuencia')

# Filter to exclude rows where QUANTITY is not equals to 1
df_filtrado = df[~df.CANTIDAD.isin([1])]
n, bins, patches = plt.hist(df_filtrado.CANTIDAD, color="gray")

# Add frequency labels above each bar, in thousands format
for i in range(len(n)):
    plt.text(bins[i] + 0.5, n[i] + 0.1, f'{int(n[i]):,}'.replace(',', '.'), ha='center', va='bottom', fontsize=10)

# Display the histogram
plt.show()
